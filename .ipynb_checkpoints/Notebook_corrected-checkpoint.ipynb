# %% [markdown]
# # Introduction
#
# Understanding the factors that influence happiness is a key topic in economics, sociology, and data science. With the availability of large-scale international datasets, it has become possible to quantitatively analyze how different economic and lifestyle indicators relate to subjective well-being across countries.
#
# This project explores the relationship between happiness levels, GDP per capita, and smoking prevalence. GDP per capita is used as an indicator of economic development, while smoking prevalence represents a lifestyle and public health factor. Happiness is measured using survey-based data from international reports.
#
# The main goal of this analysis is to investigate how these variables are related and to what extent they can explain differences in happiness across countries.
#
# ## Research Questions
# - What is the relationship between smoking prevalence and happiness across countries?
# - How does GDP per capita relate to happiness levels?
# - To what extent do smoking prevalence and GDP per capita jointly explain variations in happiness?
#
# ## Methodology
# The project follows a structured data science workflow:
# - Data collection from multiple independent sources
# - Data cleaning and preprocessing
# - Standardization of country names and formats
# - Merging datasets into a unified structure
# - Exploratory data analysis (EDA)
# - Correlation analysis
# - Linear regression modeling
#
# ## Scope and Limitations
# This study focuses on statistical relationships rather than causal effects. The analysis is conducted at the country level and does not account for individual-level differences, cultural variation, or other potential confounding factors.
#
# Despite these limitations, the project provides useful insights into global patterns of happiness and lifestyle choices and economic conditions.

# %% [markdown]
# ## Data Preparation and Preprocessing
#
# Three datasets were used in this analysis:
# - GDP per capita
# - Smoking prevalence
# - Happiness scores

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the datasets
gdp = pd.read_csv("GDP PER CAPITA.csv", sep=";", skiprows=4)
smoking = pd.read_csv("Smoking world .csv", sep=";")
happiness = pd.read_csv("World Happiness 2013-2023.csv", sep=";")

print("GDP columns:", gdp.columns.tolist()[:10], "...")
print("Smoking columns:", smoking.columns.tolist())
print("Happiness columns:", happiness.columns.tolist())
# Out:
# GDP columns: ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965'] ...
# Smoking columns: ['Entity', 'Code', 'Year', 'Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex (%) - Both sexes']
# Happiness columns: ['Country', 'Year', 'Index', 'Rank', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7']

# %% [markdown]
# The datasets were loaded from CSV files. Initial inspection showed differences in structure, naming conventions, and numeric formatting. In particular, the GDP dataset was stored in wide format, while the happiness dataset used commas as decimal separators.

# %%
# Clean and reshape GDP data
gdp.columns = gdp.columns.astype(str).str.strip()
gdp = gdp.rename(columns={"Country Name": "country"})

gdp = gdp[["country", "2020", "2021", "2022"]]
gdp = gdp.melt(
    id_vars="country",
    var_name="year",
    value_name="gdp"
)

gdp["year"] = gdp["year"].astype(int)
gdp["gdp"] = pd.to_numeric(gdp["gdp"], errors="coerce")

gdp.head()
# Out:
#                        country  year           gdp
# 0                        Aruba  2020  22759.807175
# 1  Africa Eastern and Southern  2020   1351.591669
# 2                  Afghanistan  2020    510.787063
# 3   Africa Western and Central  2020   2030.861659
# 4                       Angola  2020   1759.356199

# %% [markdown]
# The GDP dataset was originally in wide format, with years stored as separate columns. It was reshaped into long format so that each row represents a single country-year observation.

# %%
# Clean smoking data
smoking.columns = smoking.columns.str.strip()

smoking = smoking.rename(columns={
    "Entity": "country",
    "Year": "year",
    "Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex (%) - Both sexes": "smoking"
})

smoking = smoking[["country", "year", "smoking"]]
smoking["year"] = smoking["year"].astype(int)
smoking["smoking"] = pd.to_numeric(smoking["smoking"], errors="coerce")
smoking = smoking[smoking["year"].between(2020, 2022)]

smoking.head()
# Out:
#         country  year  smoking
# 4   Afghanistan  2020     23.7
# 5   Afghanistan  2022     22.7
# 10      Algeria  2020     21.2
# 11      Algeria  2022     21.2
# 16      Andorra  2020     36.0

# %% [markdown]
# The smoking dataset required column renaming and filtering to the target period 2020-2022. Only the country, year, and smoking prevalence variables were retained.

# %%
# Clean happiness data
happiness.columns = happiness.columns.str.strip()

happiness = happiness.rename(columns={
    "Country": "country",
    "Year": "year",
    "Index": "happiness"
})

happiness = happiness[["country", "year", "happiness"]]
happiness["year"] = happiness["year"].astype(int)
happiness["happiness"] = happiness["happiness"].astype(str).str.replace(",", ".", regex=False)
happiness["happiness"] = pd.to_numeric(happiness["happiness"], errors="coerce")
happiness = happiness[happiness["year"].between(2020, 2022)]

happiness.head()
# Out:
#         country  year  happiness
# 6   Afghanistan  2020      2.567
# 7   Afghanistan  2021      2.523
# 8   Afghanistan  2022      2.404
# 16      Albania  2020      4.883
# 17      Albania  2021      5.117

# %% [markdown]
# The happiness dataset required conversion of numeric values from text format because the decimal separator was stored as a comma. After conversion, the dataset was filtered to the same time period as the other sources.

# %%
# Keep only the needed columns
gdp = gdp[["country", "year", "gdp"]]
smoking = smoking[["country", "year", "smoking"]]
happiness = happiness[["country", "year", "happiness"]]

# %% [markdown]
# After standardizing names and formats, only the variables relevant to the analysis were kept. This simplifies the merge process and reduces unnecessary complexity.

# %%
# Merge the datasets
df = happiness.merge(gdp, on=["country", "year"], how="inner")
df = df.merge(smoking, on=["country", "year"], how="inner")
df = df.dropna()

df.head()
# Out:
#        country  year  happiness          gdp  smoking
# 0  Afghanistan  2020      2.567   510.787063     23.7
# 1  Afghanistan  2022      2.404   357.261153     22.7
# 2      Algeria  2020      5.005  3743.541952     21.2
# 3      Algeria  2022      5.122  4960.303343     21.2
# 4    Argentina  2020      5.975  8535.599380     24.6

# %% [markdown]
# The three datasets were merged using country and year as common keys. Rows with missing values were removed to ensure that the final analytical dataset contains complete observations for all variables.

# %%
# Final dataset check
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# Index: 248 entries, 0 to 249
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    248 non-null    str
#  1   year       248 non-null    int64
#  2   happiness  248 non-null    float64
#  3   gdp        248 non-null    float64
#  4   smoking    248 non-null    float64
# dtypes: float64(3), int64(1), str(1)
# memory usage: 11.6 KB
#               year   happiness            gdp     smoking
# count   248.000000  248.000000     248.000000  248.000000
# mean   2021.000000    5.567440   17643.258397   19.674194
# std       1.002022    1.147853   23783.740707    9.407150
# min    2020.000000    2.404000     255.832454    3.300000
# 25%    2020.000000    4.676000    2292.923904   11.900000
# 50%    2021.000000    5.692500    6527.490112   19.800000
# 75%    2022.000000    6.376250   24412.263281   25.650000
# max    2022.000000    7.821000  123719.658916   45.900000

# %% [markdown]
# The final dataset contains country-level observations with three main variables: happiness, GDP per capita, and smoking prevalence. Due to differences in data availability across sources, some countries or years may not appear in the merged dataset.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# This section explores the relationships between happiness, GDP per capita, and smoking prevalence.
#
# The goal is to identify patterns, trends, and potential correlations between the variables before applying statistical models.

# %%
df.head()
df.describe()
# Out:
#               year   happiness            gdp     smoking
# count   248.000000  248.000000     248.000000  248.000000
# mean   2021.000000    5.567440   17643.258397   19.674194
# std       1.002022    1.147853   23783.740707    9.407150
# min    2020.000000    2.404000     255.832454    3.300000
# 25%    2020.000000    4.676000    2292.923904   11.900000
# 50%    2021.000000    5.692500    6527.490112   19.800000
# 75%    2022.000000    6.376250   24412.263281   25.650000
# max    2022.000000    7.821000  123719.658916   45.900000

# %% [markdown]
# The dataset includes country-level observations with variables representing economic conditions (GDP), lifestyle behavior (smoking), and subjective well-being (happiness).

# %%
df.hist()
plt.show()

# %% [markdown]
# The distributions of the variables provide insight into their ranges and variability. GDP per capita shows a wide distribution across countries, while happiness scores are more concentrated within a narrower range.

# %%
import numpy as np

mask = np.eye(len(corr), dtype=bool)

plt.figure(figsize=(10, 8))

sns.heatmap(
    corr,
    annot=True,
    cmap="RdYlGn",
    center=0,
    mask=mask,   # hide diagonal
    fmt=".2f"
)

# draw diagonal manually
for i in range(len(corr)):
    plt.text(i + 0.5, i + 0.5, "1.00",
             ha='center', va='center',
             color='black', fontsize=10)

plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# The correlation matrix shows the strength and direction of relationships between variables.
#
# GDP per capita is expected to have a positive correlation with happiness, while smoking prevalence may show a weaker or negative relationship.

# %%
sns.scatterplot(data=df, x="gdp", y="happiness")
plt.title("GDP per Capita vs Happiness")
plt.show()

# %% [markdown]
# The scatter plot indicates a positive relationship between GDP per capita and happiness.
#
# Countries with higher economic output tend to report higher levels of happiness, although the relationship is not perfectly linear.

# %%
sns.scatterplot(data=df, x="smoking", y="happiness")
plt.title("Smoking Prevalence vs Happiness")
plt.show()

# %% [markdown]
# The relationship between smoking prevalence and happiness appears weaker and less structured compared to GDP.
#
# In some cases, higher smoking rates may be associated with lower happiness, but the pattern is not strongly pronounced.

# %% [markdown]
# Overall, GDP per capita appears to have a stronger and more consistent relationship with happiness compared to smoking prevalence.
#
# This suggests that economic conditions play significant role in explaining differences in happiness across countries than lifestyle factors such as smoking.

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df, x="gdp", y="smoking")

plt.title("GDP per Capita vs Smoking Prevalence")
plt.xlabel("GDP per Capita")
plt.ylabel("Smoking Prevalence (%)")

plt.grid(True)
plt.show()

# %%
sns.regplot(data=df, x="gdp", y="smoking", scatter=True)
plt.title("GDP vs Smoking (with trend line)")
plt.show()

# %%
df[['gdp', 'smoking']].corr()
# Out:
#               gdp   smoking
# gdp      1.000000  0.112061
# smoking  0.112061  1.000000

# %% [markdown]
# The correlation between GDP and smoking is positive but very weak (0.112), indicating that there is little to no meaningful relationship between the two variables. While the trend line shows a slight upward direction, GDP does not appear to be a strong predictor of smoking behavior. Other factors such as culture, policy, and education are likely more influential.

# %%
plt.figure(figsize=(10, 6))

scatter = plt.scatter(
    df["gdp"],
    df["happiness"],
    c=df["smoking"],
    cmap="coolwarm",   # blue → red
    alpha=0.7
)

plt.colorbar(scatter, label="Smoking prevalence (%)")

plt.xlabel("GDP per Capita")
plt.ylabel("Happiness")
plt.title("GDP vs Happiness (color = smoking)")

plt.grid(True)
plt.show()

# %% [markdown]
# Smoking prevalence is represented using a color gradient, where blue indicates lower smoking rates and red indicates higher smoking rates.
#
# This visualization improves interpretability by clearly highlighting differences in lifestyle factors across countries.
